# %%
from google.colab import drive
import sys
drive.mount('/content/drive', force_remount=True)

PATH = 'drive/MyDrive'
REPO_PATH = PATH + '/fastMRI'
DATA_PATH = PATH + '/datasets'
OUTPUT_PATH = PATH + '/modified_datasets'
ANNOTATION_PATH = REPO_PATH + '/annotations/knee.csv'
# Out:
# Mounted at /content/drive

# %%
# !pip install pytorch_lightning==1.9.4
# !pip install torchmetrics
# !pip install torchvision
# !pip install torch
# !pip install torchtext
# !pip install tqdm
# !pip install pandas
# !pip install pillow
# !pip install fastMRI
# !pip install -e {REPO_PATH}

# %% [markdown]
# #### Base unet

# %%
# !python {REPO_PATH}/fastmri_examples/unet/train_unet_demo.py \
    --challenge singlecoil \
    --data_path {DATA_PATH} \
    --annotations_path {ANNOTATION_PATH} \
    --loss wmae \
    --mask_type random \
    --accelerator cpu
# Out:
# /content/drive/MyDrive/fastMRI/fastmri/data/mri_data.py:103: UserWarning: Path config at /fastmri_dirs.yaml does not exist. A template has been created for you. Please enter the directory paths for your system to have defaults.
#   warn(
# Global seed set to 42
# Using weighted mean average error
# 13654 heatmaps generated for train set
# 2500 heatmaps generated for val set
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:478: LightningDeprecationWarning: Setting `Trainer(gpus=2)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=2)` instead.
#   rank_zero_deprecation(
# GPU available: False, used: False
# E0421 18:12:31.218172754    4682 oauth2_credentials.cc:176]            Call to http server ended with error 404 [].
# TPU available: True, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/setup.py:183: UserWarning: TPU available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='tpu', devices=8)`.
#   rank_zero_warn(
# /usr/local/lib/python3.10/dist-packages/jax/_src/cloud_tpu_init.py:73: UserWarning: JAX_USE_PJRT_C_API_ON_TPU no longer has an effect (the new TPU runtime is always enabled now). Unset the environment variable to disable this warning.
#   warnings.warn(
# [rank: 1] Global seed set to 42
# Using weighted mean average error
# 13654 heatmaps generated for train set
